# %%
import pandas as pd
from pathlib import Path

##Base_Dir=Path(_file_).parent
##file_path="\\C:\Users\Admin\Desktop\050526--DE5\Day 2"

def load_data ():

    "loading data"
    df1=pd.read_csv("03_Library Systembook.csv")
    df2=pd.read_csv("03_Library SystemCustomers.csv")
   
    return df1, df2

df1,df2=load_data() 

def data_clean (df1,df2)->tuple:

    issues_in_df1=[df1[df1["Books"].isna() | df1["Customer ID"].isna()]]

    print("Rows with missing values in Dataset 1")
    print(issues_in_df1)

    issues_in_df2=df2[df2["Customer ID"].isna()]

    print("Rows with missing values in Dataset 2")
    print(issues_in_df2)

    df1["Book Returned"]=pd.to_datetime(df1["Book Returned"], format="%d/%m/%Y")
    df1["Book checkout"]=df1["Book checkout"].astype(str).str.replace("2063","2023")
    df1["Book checkout"]=pd.to_datetime(df1["Book checkout"].astype(str).str.replace('"','', regex=False), format="%d/%m/%Y", errors="coerce")

    df1.dropna(inplace=True)
    df1.reset_index(drop=True, inplace=True)

    df2.dropna(how="all", inplace=True)
    df2.reset_index(drop=True, inplace=True)
    return df1,df2

df1,df2= data_clean(df1,df2)

def data_enrich (df1: pd.DataFrame):
    df1["Book checkout"]=df1["Book checkout"].astype(str).str.replace("2063","2023")
    df1["Book Returned"]=pd.to_datetime(df1["Book Returned"], format="%d/%m/%Y")
    
    df1["Book checkout"]=pd.to_datetime(df1["Book checkout"].astype(str).str.replace('"','', regex=False), format="%d/%m/%Y", errors="coerce")
    df1["Book checkout"]=pd.to_datetime(df1["Book checkout"], format="%d/%m/%Y")
    
    df1["new_col_name"]=df1["Book Returned"]- df1["Book checkout"].dt.days
    return df1

df1= data_enrich(df1)
print(df1)
print(df2)
# Out:
# Rows with missing values in Dataset 1
# [       Id Books Book checkout Book Returned Days allowed to borrow  \
# 20   21.0   NaN  "01/06/2023"    05/06/2023                2 weeks
# 21    NaN   NaN           NaN           NaN                    NaN
# 22    NaN   NaN           NaN           NaN                    NaN
# 23    NaN   NaN           NaN           NaN                    NaN
# 24    NaN   NaN           NaN           NaN                    NaN
# ..    ...   ...           ...           ...                    ...
# 109   NaN   NaN           NaN           NaN                    NaN
# 110   NaN   NaN           NaN           NaN                    NaN
# 111   NaN   NaN           NaN           NaN                    NaN
# 112   NaN   NaN           NaN           NaN                    NaN
# 113   NaN   NaN           NaN           NaN                    NaN
#
#      Customer ID
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# ..           ...
# 109          NaN
# 110          NaN
# 111          NaN
# 112          NaN
# 113          NaN
#
# [94 rows x 6 columns]]
# Rows with missing values in Dataset 2
#    Customer ID Customer Name
# 3          NaN           NaN
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 52
#      49     df1["new_col_name"]=df1["Book Returned"]- df1["Book checkout"].dt.days
#      50     return df1
# ---> 52 df1= data_enrich(df1)
#      53 print(df1)
#      54 print(df2)
#
# Cell In[60], line 49, in data_enrich(df1)
#      46 df1["Book checkout"]=pd.to_datetime(df1["Book checkout"].astype(str).str.replace('"','', regex=False), format="%d/%m/%Y", errors="coerce")
#      47 df1["Book checkout"]=pd.to_datetime(df1["Book checkout"], format="%d/%m/%Y")
# ---> 49 df1["new_col_name"]=df1["Book Returned"]- df1["Book checkout"].dt.days
#      50 return df1
#
# AttributeError: 'DatetimeProperties' object has no attribute 'days'
